# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import logging
logging.basicConfig(level=logging.DEBUG)
import numpy as np
import pandas as pd
import uuid
# Out:
# DEBUG:matplotlib.backends:backend module://ipykernel.pylab.backend_inline version unknown

# %%
df = pd.read_excel("../data/SPIEGEL_ONLINE_Zustand_der_Fernstraßenbrücken.xlsx")
df
# Out:
#       Bauwerksnr.                                               Name  \
# 0       1019500-0                                      B 5 / Süderau
# 1       1119503-0                            B 5 / Bosbüller Sielzug
# 2       1119504-0                  B 5 / Dreiharder Gotteskoog Strom
# 3       1119505-0                                B 5 / Kleiner Strom
# 4       1119512-0                     B 5 / Geh- und Radweg Klixbüll
# 5       1119514-0  Geh-/Radweg entl. B 5 / Dreiharder Gotteskoogs...
# 6       1122500-1  B 200 / L 16 [AS Flensburg-Duburg]/Rifa DK - H...
# 7       1122500-2  B 200 / L 16 [AS Flensburg-Duburg]/Rifa Husum ...
# 8       1122501-0                      Gem.Str. "Frösleeweg" / B 200
# 9       1122502-1  B 200 / Gem.Str. "Bauer Landstraße"/Rifa DK - ...
# 10      1122502-2  B 200 / Gem.Str. "Bauer Landstraße"/Rifa Husum...
# 11      1122503-0              B 200 / Geh- und Radweg "Klueser Weg"
# 12      1122504-0                       K 12 [FL] / B 200 [AS Klues]
# ...

# %%
#df2 = df.set_index(df["Bauwerksnr."])
#df2.drop(columns=["Bauwerksnr."], inplace=True)
#df2

# %%
df["uuid"] = df["Bauwerksnr."].apply(lambda x: uuid.uuid5(uuid.NAMESPACE_OID, x).hex)
df.head()
# Out:
#   Bauwerksnr.                               Name          Bundesland  \
# 0   1019500-0                      B 5 / Süderau  Schleswig-Holstein
# 1   1119503-0            B 5 / Bosbüller Sielzug  Schleswig-Holstein
# 2   1119504-0  B 5 / Dreiharder Gotteskoog Strom  Schleswig-Holstein
# 3   1119505-0                B 5 / Kleiner Strom  Schleswig-Holstein
# 4   1119512-0     B 5 / Geh- und Radweg Klixbüll  Schleswig-Holstein
#
#    Fläche (qm)  Baujahr  Zustandsnote 09/2014  Zustandsnote 09/2015  \
# 0         63.0   1973.0                   1.6                   1.6
# 1         49.0   1961.0                   2.3                   2.3
# 2         62.0   1905.0                   2.5                   2.5
# 3         63.0   1962.0                   2.8                   2.8
# 4         82.0   1981.0                   1.8                   1.8
#
#    Zustandsnote 03/2016  Zustandsnote 09/2016  Zustandsnote 03/2017  \
# 0                   1.6                   1.6                   1.7
# ...

# %%
df.to_hdf("../data/SPIEGEL_ONLINE_Zustand_der_Fernstraßenbrücken.h5", "bridges")
# Out:
# /home/lep/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:1471: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['Bauwerksnr.', 'Name', 'Bundesland', 'uuid']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
